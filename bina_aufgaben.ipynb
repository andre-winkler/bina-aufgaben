# %% [markdown]
# <a href="https://colab.research.google.com/github/andre-winkler/bina-aufgaben/blob/main/bina_aufgaben.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# Sicherstellen, dass Matplotlib-Diagramme direkt im Jupyter-Notebook angezeigt werden
# %matplotlib inline
# Alle Module vor der Ausführung des Codes neu laden, nützlich für die Entwicklung
# %reload_ext autoreload
# Alle Module automatisch neu laden, wenn sie geändert werden
# %autoreload 2

# %%
# Car Crashes Dataset laden
crash_df = sns.load_dataset('car_crashes')
tips_df = sns.load_dataset('tips')

# %%
# Distribution Plot Diagramm der Daten
sns.displot(crash_df['not_distracted'], kde=False, bins=25)

# %%
# Pairplot Diagramm der Daten
sns.pairplot(tips_df, hue='sex', palette='Blues')

# %%
sns.boxenplot(x='day', y='total_bill', data=tips_df, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
flights = sns.load_dataset("flights")
flights = flights.pivot_table(index='month', columns='year', values='passengers')
# You can separate data with lines
sns.heatmap(flights, cmap='Blues', linecolor='white', linewidth=1)
# Out:
# C:\Users\André Winkler\AppData\Local\Temp\ipykernel_23744\91378805.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights = flights.pivot_table(index='month', columns='year', values='passengers')
# <Axes: xlabel='year', ylabel='month'>
